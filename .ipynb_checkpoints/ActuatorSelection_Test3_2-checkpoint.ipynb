# %% [markdown]
# # Benefit of Multiplicative Models of Systems
#
# Testing actuator selection and feedback of MPL models on simulations of True system
# - Comparison to Nominal Model
# - Comparison of MPL models

# %% [markdown]
# ##### Py Packages

# %%
import numpy as np
from copy import deepcopy as dc
# %matplotlib widget

from functionfile_system_definition import sys_from_file, system_display_matrix
from functionfile_system_mplcost import simulation_model_comparison, plot_simulation_comparison1, plot_simulation_comparison2, actuator_comparison, cost_comparison_print

# %% [markdown]
# ## Code

# %%
test_set = 'System Model 9'
S_True = sys_from_file(test_set + ' C')
S_MPL = sys_from_file(test_set + ' B')
S_Nom = sys_from_file(test_set + ' A')
# Out:
# System read from file @ system_model/System Model 9 C.pickle
#
# System read from file @ system_model/System Model 9 B.pickle
#
# System read from file @ system_model/System Model 9 A.pickle

# %%
ret_sim = simulation_model_comparison(S_Nom, S_MPL, S_True)
# Out:
# ====> Breaking current simulation at t= 35 as cumulative cost magnitude exceed 1e+08
# ====> Breaking current simulation at t= 68 as cumulative cost magnitude exceed 1e+08
# ====> Breaking current simulation at t= 174 as cumulative cost magnitude exceed 1e+08

# %% [markdown]
# ## Output

# %% [markdown]
# #### System Models

# %% [markdown]
# ##### System C - True System

# %%
print('max(abs(eigvals(A)))= %.4f' % (np.max(np.abs(np.linalg.eigvals(S_True['A'])))))
system_display_matrix(S_True)
# Out:
# max(abs(eigvals(A)))= 0.8000

# %% [markdown]
# ##### System A

# %%
print('max(abs(eigvals(A)))= %.4f' % (np.max(np.abs(np.linalg.eigvals(ret_sim['system_A']['A'])))))
system_display_matrix(ret_sim['system_A'])
# Out:
# max(abs(eigvals(A)))= 0.8000

# %% [markdown]
# ##### System B

# %%
print('max(abs(eigvals(A)))= %.4f' % (np.max(np.abs(np.linalg.eigvals(ret_sim['system_B']['A'])))))
system_display_matrix(ret_sim['system_B'])
# Out:
# max(abs(eigvals(A)))= 0.8000

# %% [markdown]
# #### Simulation - Trajectory, Control Input and Costs

# %%
plot_simulation_comparison1(ret_sim)

# %% [markdown]
# #### Actuator set comparison

# %%
actuator_comparison(ret_sim['system_B'], ret_sim['system_A'], disptext=True, figplt=True);
# Out:
# Control sets are different

# %% [markdown]
# #### Simulated costs

# %%
cost_comparison_print(ret_sim)
# Out:
# True system (System Model 9 C) simulation cost with A (System Model 9 A) and B (System Model 9 B) feedback
# |S|: 1 | A: 1.9887e+04 | B: nan | Diff (A-B) nan (nan % of A)
# |S|: 2 | A: 7.1824e+03 | B: nan | Diff (A-B) nan (nan % of A)
# |S|: 3 | A: 3.3058e+04 | B: nan | Diff (A-B) nan (nan % of A)
# |S|: 4 | A: 5.0409e+03 | B: 2.2979e+03 | Diff (A-B) 2.7429e+03 (54.41 % of A)
# |S|: 5 | A: 3.0134e+03 | B: 2.2077e+03 | Diff (A-B) 8.0561e+02 (26.73 % of A)
# |S|: 6 | A: 2.5833e+03 | B: 2.1494e+03 | Diff (A-B) 4.3386e+02 (16.79 % of A)
# |S|: 7 | A: 2.3753e+03 | B: 2.1424e+03 | Diff (A-B) 2.3291e+02 (9.81 % of A)
# |S|: 8 | A: 2.0631e+03 | B: 2.1270e+03 | Diff (A-B) -6.3942e+01 (-3.10 % of A)

# %%
plot_simulation_comparison2(ret_sim)

# %% [markdown]
# ## Run Complete

# %%
print('Run Complete')
# Out:
# Run Complete
