# %% [markdown]
# # Benefit of MPL System Modelling
# True, Nominal, MPL model testing

# %% [markdown]
# ##### Py Packages

# %%
import numpy as np
from copy import deepcopy as dc

from functionfile_system_definition import sys_from_file
from functionfile_system_mplcost import simulation_nom_vs_mpl, plot_simulation_nom_vs_mpl_1, plot_simulation_nom_vs_mpl_2

# %% [markdown]
# ## Code

# %%
test_set = 'System Model 1'
S_True = sys_from_file(test_set + ' True')
S_MPL = sys_from_file(test_set + ' MPL')
S_Nom = sys_from_file(test_set + ' Nominal')
# Out:
# System read from file @ system_model/System Model 1 True.pickle
#
# System read from file @ system_model/System Model 1 MPL.pickle
#
# System read from file @ system_model/System Model 1 Nominal.pickle

# %%
ret_sim = simulation_nom_vs_mpl(S_Nom, S_MPL, S_True)

# %% [markdown]
# ## Output

# %%
plot_simulation_nom_vs_mpl_1(ret_sim)

# %%
print('True simulation on <___> model feedback')
for key in ret_sim['T_Nom']['costs']:
    print('|S|:', key, '| Nom:', ret_sim['T_Nom']['costs'][key][-1], '| MPL:', ret_sim['T_MPL']['costs'][key][-1], ' | Diff (Nom-MPL):', ret_sim['T_Nom']['costs'][key][-1]-ret_sim['T_MPL']['costs'][key][-1])
# Out:
# True simulation on <___> model feedback
# |S|: 1 | Nom: 26291.62242943204 | MPL: 26277.509576623488  | Diff (Nom-MPL): 14.112852808550088
# |S|: 2 | Nom: 19728.395106475327 | MPL: 19678.861831358034  | Diff (Nom-MPL): 49.53327511729367
# |S|: 3 | Nom: 15758.239948443026 | MPL: 14833.128300969829  | Diff (Nom-MPL): 925.1116474731971
# |S|: 4 | Nom: 15037.781788073695 | MPL: 13434.096836314071  | Diff (Nom-MPL): 1603.6849517596238
# |S|: 5 | Nom: 13415.911551800564 | MPL: 12664.675256960852  | Diff (Nom-MPL): 751.2362948397113
# |S|: 6 | Nom: 12206.034460294995 | MPL: 11895.966295995111  | Diff (Nom-MPL): 310.0681642998843
# |S|: 7 | Nom: 11791.658714527373 | MPL: 11431.45612083109  | Diff (Nom-MPL): 360.20259369628366
# |S|: 8 | Nom: 11410.699007800713 | MPL: 11018.894649090655  | Diff (Nom-MPL): 391.8043587100583
# |S|: 9 | Nom: 10753.798575859497 | MPL: 10624.28510726364  | Diff (Nom-MPL): 129.51346859585647
# |S|: 10 | Nom: 10298.403909709761 | MPL: 10220.300842380952  | Diff (Nom-MPL): 78.10306732880963

# %%
plot_simulation_nom_vs_mpl_2(ret_sim)
