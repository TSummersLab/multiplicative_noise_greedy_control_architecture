# %% [markdown]
# # Benefits of MPL Modeling for Actuator Selection - Random Graph (Erdos-Renyi) analysis
#
# Statistics on the benefits of multiplicative noise modelling for actuator selection over N realizations of Erdos-Renyi random graphs

# %% [markdown]
# ##### Py Packages

# %%
import numpy as np
from copy import deepcopy as dc
# %matplotlib widget

from functionfile_system_definition import create_graph, system_package
from functionfile_system_mplcost import random_graph_emperical_simulation, plot_random_graph_simulation

# %% [markdown]
# ### Test Parameters

# %%
# Number of test iterations
N_test = 20

# Edge probability
edge_probability = 0.5

# Network parameters
nx = 10           # Number of nodes
rho = 0.7        # Open-loop stability (unsigned magnitude of largest eigenvalue of dynamics matrix)
alphai = [0.3]    # Covariance on state-dependent multiplicative noise

# Initial state - realization of distribution given mean and covariance 
X0_cov = 10*np.identity(nx)
X0_mean = np.zeros(nx)

# %% [markdown]
# ### Code

# %%
X0 = np.random.default_rng().multivariate_normal(mean=X0_mean, cov=X0_cov)
S_base_model = system_package(A_in=rho*create_graph(nx)['A'], alphai_in=alphai, Ai_in=create_graph(nx)['A'], X0_in=X0, label_in='System Model', print_check=False)

# %%
simulation_values = random_graph_emperical_simulation(S_base_model, edge_probability, N_test)
# Out:
# ====> Breaking current simulation at t= 12 as cumulative cost magnitude exceed 1e+08
# ====> Breaking current simulation at t= 15 as cumulative cost magnitude exceed 1e+08
# Realization: 20 / 20

# %% [markdown]
# ### Plot

# %%
plot_random_graph_simulation(simulation_values)
# Out:
# D:\Anaconda\envs\work\lib\site-packages\numpy\linalg\linalg.py:2158: RuntimeWarning: invalid value encountered in det
#   r = _umath_linalg.det(a, signature=signature)

# %%
print(simulation_values['MPL_costs'])
# Out:
# [[ 248.50613181  246.94935825  254.90774266  261.22179658  254.79590382
#    253.12067219  252.95556685  252.0661166   249.58296644  245.05622025]
#  [          nan  646.44601541  302.32544221  271.78167902  259.80705121
#    252.43767116  250.80481543  248.87035967  248.8745381   248.9104942 ]
#  [ 286.16391067 1533.14727625  257.32537079  254.37550696  247.18869772
#    246.46071686  246.0140331   245.92966587  246.004727    244.03174169]
#  [ 273.31470437  271.30007602  269.65303673  326.35423168  267.26095904
#    263.83526479  254.62424885  258.6410318   258.02020979  253.20938937]
#  [ 246.43878988  248.46878555  246.76940737  246.73430842  246.61374089
#    246.59446349  246.59381861  249.29372333  248.86194862  248.9399544 ]
#  [ 249.86590031  251.79551553  260.84766086  247.7676411   245.36229677
#    245.61864293  245.45719486  245.86355747  245.35639005  245.52238595]
#  [ 251.2633571   246.88132272  253.21293951  246.84877602  244.86389684
#    247.21532518  247.2862752   247.89167828  247.93358105  247.39916254]
#  [ 330.0192019  1976.55447196  320.46052733  288.3381684   274.79630622
#    263.91974053  259.31750954  256.6874617   256.67496985  256.10780047]
#  [ 257.11108503  249.44613206  249.02317767  250.64522943  248.67283785
#    248.75807245  250.02481639  248.43918436  249.13846163  247.91598453]
#  [ 244.69045144  243.70465357  306.76079995  254.60002806  254.51321555
#    245.36099917  245.40401463  244.46695697  243.82280869  243.27057001]
#  [ 258.86000963  256.75955527  264.90683849  258.77024785  248.03066335
#    249.79993535  249.90673165  249.91593273  250.62466942  250.50348833]
#  [ 249.22427294  334.90178132  274.76027185  263.65689364  259.15865545
#    261.03863606  261.47374396  261.99589619  263.31605206  256.40955941]
#  [ 252.18242843  269.59829584  270.32569099  261.94454718  244.20466957
#    243.77905997  243.29481347  243.62696011  243.34094157  244.32392958]
#  [          nan  257.24135319  253.50205071  245.48910373  246.20066337
#    246.31854209  246.32632667  246.23778375  245.86408777  245.33703721]
#  [ 248.38862365  249.08201154  245.71552534  245.0772183   243.85925254
#    244.48193499  244.06774668  243.75818884  243.71462264  244.77773662]
#  [ 249.40899727  243.84428648  247.78190919  245.84724008  250.98561575
#    250.56537791  249.79024197  248.28896358  248.09209422  248.72335482]
#  [ 247.41754296  245.03950404  245.31504356  244.47539174  244.11972784
#    245.75972189  246.06012275  246.87049723  246.84507943  246.8005016 ]
#  [ 250.05620173  252.44307271  250.06911198  247.18182483  248.8621531
#    249.24882125  249.47718294  245.42635821  245.05188179  245.16385443]
#  [ 278.1420686   586.47992903  277.64438281  277.87835492  276.98205349
#    262.39660074  254.56669441  256.07908314  254.21948421  252.31558287]
#  [ 254.33884348  254.33304081  257.54117129  257.96654274  255.80310291
#    249.72702542  251.94786721  250.53965203  250.58172596  250.57155976]]

# %% [markdown]
# ## Run Complete

# %%
print('Run Complete')
# Out:
# Run Complete
